# %%
import pandas as pd
from datetime import datetime,timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as myDate
plt.style.use('seaborn')
import seaborn as sns
from pylab import rcParams

rcParams['figure.figsize']=15,14
sns.set_style('whitegrid')

# %% [markdown]
#  Extracting Dataset

# %%
dataset=pd.read_csv(r"C:\Users\IDEAPAD\dataset\data.csv")

# %%
dataset.head()
# Out:
#      rates__|  rates__|__CAD  rates__|__HKD  rates__|__ISK  rates__|__PHP  \
# 0  2020-02-11         1.4495         8.4658          137.9         55.061
# 1  2020-01-09         1.4505         8.6317          137.7         56.250
# 2  2020-03-09         1.5613         8.9041          145.0         58.013
# 3  2020-01-03         1.4471         8.6713          136.9         56.983
# 4  2020-02-19         1.4281         8.3925          138.1         54.616
#
#    rates__|__DKK  rates__|__HUF  rates__|__CZK  rates__|__AUD  rates__|__RON  \
# 0         7.4721         337.93         24.965         1.6260         4.7693
# 1         7.4731         332.51         25.253         1.6193         4.7785
# 2         7.4695         336.25         25.504         1.7330         4.8175
# 3         7.4731         330.53         25.360         1.6031         4.7784
# 4         7.4693         336.33         24.962         1.6142         4.7792
#
#    ...  rates__|__ZAR  rates__|__USD  rates__|__MXN  rates__|__ILS  \
# 0  ...        16.2331         1.0901        20.3563         3.7200
# 1  ...        15.7839         1.1110        20.8637         3.8556
# 2  ...        18.2898         1.1456        24.3268         4.0275
# 3  ...        15.9222         1.1147        21.1433         3.8766
# 4  ...        16.1425         1.0800        20.0690         3.6946
#
#    rates__|__GBP  rates__|__KRW  rates__|__MYR    start_at  base      end_at
# 0        0.84325        1290.63         4.5059  2020-01-01   EUR  2020-07-16
# 1        0.85285        1288.28         4.5445         NaN   NaN         NaN
# 2        0.87383        1374.71         4.8304         NaN   NaN         NaN
# 3        0.85115        1300.32         4.5725         NaN   NaN         NaN
# 4        0.83148        1284.75         4.4955         NaN   NaN         NaN
#
# [5 rows x 36 columns]

# %%
dataset.columns
# Out:
# Index(['rates__|', 'rates__|__CAD', 'rates__|__HKD', 'rates__|__ISK',
#        'rates__|__PHP', 'rates__|__DKK', 'rates__|__HUF', 'rates__|__CZK',
#        'rates__|__AUD', 'rates__|__RON', 'rates__|__SEK', 'rates__|__IDR',
#        'rates__|__INR', 'rates__|__BRL', 'rates__|__RUB', 'rates__|__HRK',
#        'rates__|__JPY', 'rates__|__THB', 'rates__|__CHF', 'rates__|__SGD',
#        'rates__|__PLN', 'rates__|__BGN', 'rates__|__TRY', 'rates__|__CNY',
#        'rates__|__NOK', 'rates__|__NZD', 'rates__|__ZAR', 'rates__|__USD',
#        'rates__|__MXN', 'rates__|__ILS', 'rates__|__GBP', 'rates__|__KRW',
#        'rates__|__MYR', 'start_at', 'base', 'end_at'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (138, 36)

# %%
dataset.sort_values('rates__|',inplace=True)
dataset1=dataset.head(22)
dataset1
# Out:
#        rates__|  rates__|__CAD  rates__|__HKD  rates__|__ISK  rates__|__PHP  \
# 77          4.7795  ...        16.0274         1.1115        20.9406
# 51          4.7803  ...        16.0218         1.1142        20.9542
# 85          4.7790  ...        16.1229         1.1169        20.9901
# 44          4.7803  ...        16.0582         1.1108        20.8338
# 30          4.7794  ...        16.1045         1.1085        20.6940
# 37          4.7785  ...        16.0899         1.1115        20.8194
# 92          4.7784  ...        15.9750         1.1088        20.7417
# 29          4.7788  ...        15.9503         1.1091        20.7527
# 50          4.7799  ...        15.8585         1.1035        20.7170
# 120         4.7808  ...        16.0431         1.1025        20.8715
# 34          4.7784  ...        16.1249         1.1005        20.7316
# 56          4.7770  ...        16.0719         1.1001        20.6109
# 48          4.7770  ...        16.2673         1.1029        20.6985
# 41          4.7789  ...        16.4900         1.1052        20.8044
#
#      rates__|__ILS  rates__|__GBP  rates__|__KRW  rates__|__MYR  start_at  \
# 131         3.8690        0.84828        1298.24         4.5764       NaN
# 3           3.8766        0.85115        1300.32         4.5725       NaN
# 52          3.8913        0.85215        1308.83         4.5940       NaN
# 68          3.8731        0.85183        1302.48         4.5727       NaN
# 15          3.8541        0.84868        1297.37         4.5588       NaN
# 1           3.8556        0.85285        1288.28         4.5445       NaN
# 78          3.8476        0.84810        1286.00         4.5212       NaN
# 18          3.8604        0.85760        1288.09         4.5199       NaN
# 77          3.8541        0.85618        1285.74         4.5288       NaN
# 51          3.8561        0.85683        1289.22         4.5409       NaN
# 85          3.8575        0.85470        1293.87         4.5377       NaN
# 44          3.8372        0.85105        1288.37         4.5041       NaN
# 30          3.8326        0.85275        1286.08         4.5022       NaN
# 37          3.8405        0.85030        1298.12         4.5255       NaN
# 92          3.8279        0.84445        1290.57         4.5078       NaN
# 29          3.8336        0.84498        1295.15         4.5140       NaN
# 50          3.8100        0.84313        1289.12         4.4857       NaN
# 120         3.8151        0.84358        1298.34         4.4822       NaN
# 34          3.8033        0.84603        1297.20         4.4972       NaN
# 56          3.8053        0.84580        1296.65         4.4884       NaN
# 48          3.8080        0.84183        1315.00         4.5087       NaN
# 41          3.8090        0.84175        1321.60         4.5297       NaN
#
#      base  end_at
# 131   NaN     NaN
# 3     NaN     NaN
# 52    NaN     NaN
# 68    NaN     NaN
# 15    NaN     NaN
# 1     NaN     NaN
# 78    NaN     NaN
# 18    NaN     NaN
# 77    NaN     NaN
# 51    NaN     NaN
# 85    NaN     NaN
# 44    NaN     NaN
# 30    NaN     NaN
# 37    NaN     NaN
# 92    NaN     NaN
# 29    NaN     NaN
# 50    NaN     NaN
# 120   NaN     NaN
# 34    NaN     NaN
# 56    NaN     NaN
# 48    NaN     NaN
# 41    NaN     NaN
#
# [22 rows x 36 columns]

# %% [markdown]
# #[T-1] Plot the graph of INR exchange rate against EUR from 1 Jan 2019 to 31 Jan 2019

# %%
date=list(dataset1['rates__|'])
date
INR=list(dataset1['rates__|__INR'])

# %%
plt.plot_date(date,INR,linestyle='solid')
plt.gcf().autofmt_xdate()
